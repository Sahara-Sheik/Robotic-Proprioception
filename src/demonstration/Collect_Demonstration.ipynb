# %% [markdown]
# # Collect demonstrations
#
# Interactive notebook for collecting demonstrations

# %%
# %matplotlib auto

import sys
sys.path.append("..")
from exp_run_config import Config
Config.PROJECTNAME = "BerryPicker"

import pathlib
import socket
from datetime import datetime
from demonstration_recorder import DemonstrationRecorder

# the gamepad is only available on some machines, and only on Linux
available_gamepad = True
try:
    from robotcontrol.gamepad_controller import GamepadController
except ModuleNotFoundError:
    print("Approxeng module not found, cannot use gamepad")
    available_gamepad = False
    
from robotcontrol.keyboard_controller import KeyboardController
from robotcontrol.automove_controller import AutoMoveController
from robot.al5d_position_controller import PositionController
from robot.al5d_simulated_position_controller import SimulatedPositionController


from camera.camera_controller import CameraController
from demonstration import Demonstration
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
experiment = "demonstration_collector"
# picking up a collection specific name
hostname = socket.gethostname()
print(f"Hostname is {hostname}")
if hostname == "raven":
    run = "collect_freeform_raven"
elif hostname == "szenes.local":
    run = "collect_no_robot"
elif hostname == "tredy2":
    run = "tredy2_collect_freeform"
    run = "tredy2_automove_rwp6d_00"
else:
    run = "collect_freeform"

exp = Config().get_experiment(experiment, run)
exp_target = Config().get_experiment("demonstration", exp["demonstration_name"])
exp_position_controller = Config().get_experiment(
    exp["exp_position_controller"], 
    exp["run_position_controller"])

exp_camera_controller = Config().get_experiment(exp["exp_camera_controller"], exp["run_camera_controller"])
exp_keyboard_controller = Config().get_experiment(exp["exp_keyboard_controller"], exp["run_keyboard_controller"])
exp_gamepad_controller = Config().get_experiment(exp["exp_gamepad_controller"], exp["run_gamepad_controller"])
exp_automove_controller = Config().get_experiment(exp["exp_automove_controller"], exp["run_automove_controller"])
# Out:
# Hostname is tredy2
# ***ExpRun**: Configuration for exp/run: demonstration_collector/tredy2_automove_rwp6d_00 successfully loaded
# ***ExpRun**: Configuration for exp/run: demonstration/freeform successfully loaded
# ***ExpRun**: Configuration for exp/run: robot_al5d/position_controller_00 successfully loaded
# ***ExpRun**: Experiment default config /home/lboloni/Documents/Hackingwork/_Checkouts/BerryPicker/BerryPicker/src/experiment_configs/controllers/_defaults_controllers.yaml was empty, ok.
# ***ExpRun**: Configuration for exp/run: controllers/camera_controller_tredy2 successfully loaded
# ***ExpRun**: Experiment default config /home/lboloni/Documents/Hackingwork/_Checkouts/BerryPicker/BerryPicker/src/experiment_configs/controllers/_defaults_controllers.yaml was empty, ok.
# ***ExpRun**: Configuration for exp/run: controllers/keyboard_controller successfully loaded
# ***ExpRun**: Experiment default config /home/lboloni/Documents/Hackingwork/_Checkouts/BerryPicker/BerryPicker/src/experiment_configs/controllers/_defaults_controllers.yaml was empty, ok.
# ***ExpRun**: Configuration for exp/run: controllers/gamepad_x360_controller successfully loaded
# ***ExpRun**: Configuration for exp/run: automove/automove_random_waypoint_6D_00 successfully loaded

# %%
# This was here to debug things, because it was not finding one of the cameras
import cv2

# identifying which cameras work
for i in range(10):
    cap = cv2.VideoCapture(i)
    ret, frame = cap.read()
    if ret:
        print(f"Camera {i} is working")
    else:
        print(f"Camera {i} not working")
    cap.release()
# Out:
# Camera 0 not working
# [ WARN:0@228.567] global cap_v4l.cpp:999 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@228.568] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# Camera 1 is working
# Camera 2 is working
# Camera 3 not working
# Camera 4 not working
# Camera 5 not working
# Camera 6 not working
# Camera 7 not working
# Camera 8 not working
# Camera 9 not working
# [ WARN:0@230.563] global cap_v4l.cpp:999 open VIDEOIO(V4L2:/dev/video3): can't open camera by index
# [ERROR:0@230.564] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@230.564] global cap_v4l.cpp:999 open VIDEOIO(V4L2:/dev/video4): can't open camera by index
# [ERROR:0@230.564] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@230.564] global cap_v4l.cpp:999 open VIDEOIO(V4L2:/dev/video5): can't open camera by index
# [ERROR:0@230.565] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@230.565] global cap_v4l.cpp:999 open VIDEOIO(V4L2:/dev/video6): can't open camera by index
# [ERROR:0@230.566] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@230.566] global cap_v4l.cpp:999 open VIDEOIO(V4L2:/dev/video7): can't open camera by index
# [ERROR:0@230.566] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@230.566] global cap_v4l.cpp:999 open VIDEOIO(V4L2:/dev/video8): can't open camera by index
# [ERROR:0@230.567] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@230.567] global cap_v4l.cpp:999 open VIDEOIO(V4L2:/dev/video9): can't open camera by index
# [ERROR:0@230.567] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range

# %%
# starting the robot controller
if exp["available_robot"]:
    robot_controller = PositionController(exp_position_controller)
else:
    robot_controller = SimulatedPositionController(exp_position_controller)
# starting the camere controller
camera_controller = CameraController(exp_camera_controller)
camera_controller.visualize = True


task_dir = exp_target.data_dir()
demoname = datetime.now().strftime('%Y_%m_%d__%H_%M_%S')
demo_dir = pathlib.Path(task_dir, demoname)
demo_dir.mkdir(parents=False, exist_ok=False)
print(f"Ok, demonstration with go into\n\t {demo_dir}")

demonstration = Demonstration(exp_target, demoname, parse_old_style = False)
demonstration.metadata["cameras"] = sorted(camera_controller.capture_devs.keys())
demonstration.save_metadata()
# fixme need to add the cameras into the demonstration
# Out:
# ***ExpRun**: Configuration for exp/run: robot_al5d/pulse_controller_00 successfully loaded
# ***ExpRun**: Configuration for exp/run: robot_al5d/angle_controller_00 successfully loaded
# Try out the backup /dev/ttyUSB0
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# cap1 works
# cap2 works
# Ok, demonstration with go into
# 	 /home/lboloni/Documents/Hackingwork/__Temporary/BerryPicker-experiments/demonstration/freeform/2025_10_12__15_13_39

# %%
# Performs the recording. The robot is controlled through the primary 
# controller. This is also used to terminate the collection
# The information is collected by the demonstration recorder

controller = exp["primary_controller"]

if controller == "xbox":
    gamepad_controller = GamepadController(exp_gamepad_controller,
        robot_controller=robot_controller, camera_controller=camera_controller)
    demo_recorder = DemonstrationRecorder(demonstration,
        camera_controller=camera_controller, remote_control=gamepad_controller, robot_controller=
                                robot_controller, save_dir=demo_dir)
    # dr = None
    gamepad_controller.demonstration_recorder = demo_recorder
    gamepad_controller.control()
    demonstration.save_metadata()
    print("====== Demonstration terminated and recorded successfully, bye. ======")
if controller == "keyboard":
    kb_controller = KeyboardController(exp_keyboard_controller,
        robot_controller=robot_controller, camera_controller=camera_controller)
    demo_recorder = DemonstrationRecorder(demonstration, camera_controller=camera_controller, remote_control=kb_controller, robot_controller=
                                robot_controller, save_dir=demo_dir)
    # dr = None
    kb_controller.demonstration_recorder = demo_recorder
    kb_controller.control()
    demonstration.save_metadata()
    print("====== Demonstration terminated and recorded successfully, bye. ======")

if controller == "automove":
    automove_controller = AutoMoveController(exp_automove_controller,
        robot_controller=robot_controller, camera_controller=camera_controller)
    automove_controller.generate_waypoints()
    # program_controller.interactive_confirm = False
    demo_recorder = DemonstrationRecorder(demonstration, camera_controller=camera_controller, remote_control=automove_controller, robot_controller=
                                robot_controller, save_dir=demo_dir)
    automove_controller.demonstration_recorder = demo_recorder
    demonstration.save_metadata()
    automove_controller.control()
# Out:
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# added waypoint Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# added waypoint Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# added waypoint Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# added waypoint Position:
#  height:3.93
#  distance:7.94
#  heading:27.22
#  wrist_angle:-78.65
#  wrist_rotation:80.43
#  gripper:48.81
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# added waypoint Position:
#  height:1.63
#  distance:9.69
#  heading:-20.18
#  wrist_angle:-1.33
#  wrist_rotation:74.57
#  gripper:20.97
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# added waypoint Position:
#  height:3.27
#  distance:9.63
#  heading:52.50
#  wrist_angle:-19.99
#  wrist_rotation:85.19
#  gripper:11.58
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# added waypoint Position:
#  height:1.01
#  distance:7.49
#  heading:-34.93
#  wrist_angle:-16.50
#  wrist_rotation:78.83
#  gripper:71.65
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# added waypoint Position:
#  height:2.68
#  distance:7.33
#  heading:-68.24
#  wrist_angle:-51.93
#  wrist_rotation:72.97
#  gripper:86.22
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# added waypoint Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# added waypoint Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.32698532442251843
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.3051599288980166
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.2833345259229342
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.261509137849013
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.23968373984098432
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.21849640955527622
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.20091702789068222
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.18425035228331882
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.17261179039875665
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.1642784501115481
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.15594511975844702
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.1476117894053459
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.1392784540851911
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.13094512373208997
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.12261178344488143
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.11427845309178035
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.10833928485711415
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.10278371969858804
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.09722816944122314
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.09167260924975076
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.08611705899238586
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.08056149880091348
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.07500594357649484
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.06945039331912994
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.0638948380947113
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.05833927790323893
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.05278372267882028
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.04722816745440165
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.04167261719703674
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.03611705700556437
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.03132254381974538
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.029933651288350422
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.028544763724009194
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.02715587615966797
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.02576698859532674
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.024378096063931782
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.022989208499590554
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.02160032093524933
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.02021143212914467
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.018822542081276573
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.01743365451693535
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.016044764469067253
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.014655876904726028
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.013266986856857935
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.011878099292516708
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.010489209244648615
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.009100320438543955
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.007711431632439295
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.006322542826334635
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.004933654020229975
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.003544765214125315
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.002155876408020655
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.02
#  distance:5.54
#  heading:-78.83
#  wrist_angle:-67.71
#  wrist_rotation:72.61
#  gripper:63.02
#  at distance 0.0007669876019159952
# New waypoint: Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.26624036331971485
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.25088962912559504
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.24252970019976297
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.2359820852677027
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.22943446536858875
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.2228868454694748
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.21633923053741452
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.20979161063830057
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.20324399570624033
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.19669637580712634
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.19014876584211984
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.18360113104184467
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.17705351114273069
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.17050589621067047
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.1639582763115565
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.15741066137949625
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.15086304148038227
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.1443154215812683
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.13776779174804688
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.13122018178304035
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.12467256188392639
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.11812494198481241
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.11157732208569844
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.1050297071536382
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.09848208725452423
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.0921666572491328
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.0879999945561091
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.08383332689603169
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.07966666420300801
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.07549999157587688
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.07160895069440205
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.0702200581630071
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.06883117059866586
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.06744228303432465
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.06605339546998341
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.06466450293858846
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.06327561537424722
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.061886727809906006
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.06049783527851105
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.059108947714169816
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.05772006014982859
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.056331172585487366
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.05494228005409241
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.053553392489751175
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.05216450492540995
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.050775617361068726
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.04938672482967377
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.047997837265332535
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.04660894970099131
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.045220062136650085
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.04383116960525513
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.042442282040913895
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.04105339447657267
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.039664506912231445
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.038275619347890213
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.03688672184944153
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.035497834285100296
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.03410894672075907
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.03272005915641785
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.031331171592076615
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.02994228402773539
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.028553396463394165
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.027164508899052937
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.025775611400604248
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.02438672383626302
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.02299783627192179
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.021608948707580566
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.020220061143239338
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.01883117357889811
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.017442286014556885
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.016053388516108193
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.014664500951766968
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.01327561338742574
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.011886725823084513
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.010497838258743286
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.009108950694402058
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.007720063130060831
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.0063311755657196045
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.004942278067270914
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.0035533905029296875
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.00216450293858846
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.06
#  distance:8.13
#  heading:45.84
#  wrist_angle:-21.36
#  wrist_rotation:73.20
#  gripper:51.93
#  at distance 0.000775615374247233
# New waypoint: Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.1964020729064941
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.17457667986551922
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.1530481179555257
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.1340004950761795
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.11686543126900989
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.10673014322916666
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.09879363079865773
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.09085712830225626
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.08292062083880106
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.07562858859697977
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.07007303833961487
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.06451747814814249
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.05896191795667012
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.053406367699305214
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.04785080750783285
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.042295257250467934
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.03749514619509379
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.036106258630752563
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.03471736113230387
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.033328473567962646
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.031939586003621415
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.03055069843928019
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
#  distance:9.10
#  heading:-20.99
#  wrist_angle:-17.02
#  wrist_rotation:71.04
#  gripper:25.61
#  at distance 0.029161810874938965
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:3.74
# ...
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.059531169633070626
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.05576132486263911
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.05199148505926132
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.04822164525588353
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.044451805452505745
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.04068196068207423
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.03691212087869644
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.03314228107531865
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.029372441271940865
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.025602596501509346
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.02183275669813156
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.018062916894753773
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.014293072124322254
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.010523232320944468
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.006753392517566681
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.004007868468761444
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.001626916229724884
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:2.04
#  distance:3.66
#  heading:-16.84
#  wrist_angle:-76.68
#  wrist_rotation:71.39
#  gripper:13.00
#  at distance 0.0
# New waypoint: Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.3694583848118782
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.3476329818367958
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.325807586312294
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.3039821982383728
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.2861517940958341
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.2684930587808291
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.25083432843287784
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.23317560305198032
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.21551686028639475
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.19785813987255096
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.1801994095245997
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.16254067917664844
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.14648122588793436
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.1371558258930842
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.1278304358323415
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.11850503087043762
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.11006257434686025
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.10311812659104665
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.09617368876934052
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.08922923604647318
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.08228479574124017
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.07534035295248032
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.06839591264724731
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.061451464891433716
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.05450701465209325
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.047562576830387115
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.040618136525154114
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.033673676351706185
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.02672923853000005
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.021319478750228882
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.017152806123097736
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.014370898405710856
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.0115931232770284
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.008815348148345947
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.00603756308555603
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.0032597879568735757
# {'height': 5.0, 'distance': 5.0, 'heading': 0.0, 'wrist_angle': -45.0, 'wrist_rotation': 75.0, 'gripper': 100}
# *** next_pos: next waypoint is Position:
#  height:1.64
#  distance:5.32
#  heading:-63.35
#  wrist_angle:-32.51
#  wrist_rotation:89.98
#  gripper:77.04
#  at distance 0.0004820128281911214
# Finished waypoints
# ***al5d_position_controller: Initiating the stopping of the robot
# ***al5d_position_controller: Robot stopped

# %%
demonstration.save_metadata()
demonstration.move_to_video(delete_img_files=True)
# Out:
# ***Demonstration***: moving to video started
# move to video per camera dev1
# move to video per camera dev2
# ***Demonstration***: moving to video done

# %%
print(demonstration.metadata)
# Out:
# {'stored_as_video': True, 'stored_as_images': False, 'maxsteps': 475, 'cameras': ['dev1', 'dev2']}

# %%
exp
# Out:
# Experiment:
#     available_robot: true
#     data_dir: /home/lboloni/Documents/Hackingwork/__Temporary/BerryPicker-experiments/demonstration_collector/tredy2_automove_rwp6d_00
#     demonstration_name: freeform
#     exp_automove_controller: automove
#     exp_camera_controller: controllers
#     exp_gamepad_controller: controllers
#     exp_keyboard_controller: controllers
#     exp_position_controller: robot_al5d
#     exp_run_sys_indep_file: /home/lboloni/Documents/Hackingwork/_Checkouts/BerryPicker/BerryPicker/src/experiment_configs/demonstration_collector/tredy2_automove_rwp6d_00.yaml
#     experiment_name: demonstration_collector
#     primary_controller: automove
#     run_automove_controller: automove_random_waypoint_6D_00
#     run_camera_controller: camera_controller_tredy2
#     run_gamepad_controller: gamepad_x360_controller
#     run_keyboard_controller: keyboard_controller
#     run_name: tredy2_automove_rwp6d_00
#     run_position_controller: position_controller_00
#     subrun_name: null
